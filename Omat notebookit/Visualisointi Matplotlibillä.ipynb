# %% [markdown]
# # Matplotlib

# %% [markdown]
# * Peruskirjasto (matemaattiseen) mallinnukseen
# * Tehokas mutta monimutkainen

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot([1, 2, 3, 4])
plt.ylabel("numeroita")
#plt.show()

# %%
plt.plot( [1, 2, 3 ,4], [1, 4, 1, 8])

# %%
plt.plot( [1, 2, 3 ,3.5], [1, 4, 1, 6], "ro")
plt.axis([0, 10, 0, 15])
# "ro" on plotin väri ja tyyppi, tulee MATLABista
# Out:
# [0, 10, 0, 15]

# %%
import numpy as np

t = np.arange(0., 5., 0.2)

plt.plot(t, t, "r--", t, t**2, "bs", t, t**3, "g^")
# Out:
# [<matplotlib.lines.Line2D at 0x92a0080>,
#  <matplotlib.lines.Line2D at 0x92a0320>,
#  <matplotlib.lines.Line2D at 0x92a0b70>]

# %% [markdown]
# ### Useita figureita

# %%
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure(1)
plt.subplot(211)
plt.plot(t1, f(t1), "bo", t2, f(t2), "k")

plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), "r--")

# %%
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

n, bins, patches = plt.hist(x, 50, normed = 1, facecolor = "g", alpha = 0.75)

plt.xlabel("Smarts")
plt.ylabel("Probability")
plt.title("Histogram of IQ")
plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.axis( [40, 160, 0, 0.03])
plt.grid(True)
