# %% [markdown]
# # Pandas

# %% [markdown]
# * Pandas kykynee myös visualisointiin
# * Perustuu matplotlibiin

# %%
import pandas as pd

# %%
budget = pd.read_csv("mn-budget-detail-2014.csv")
budget = budget.sort("amount", ascending = False)[:10]
# Out:
# C:\Users\mikkok\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   from ipykernel import kernelapp as app

# %%
pd.options.display.mpl_style = "default"

budget_plot = budget.plot(kind = "bar", x = budget["detail"], title = "Otsikko", legend = False)
# Out:
# C:\Users\mikkok\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2881: FutureWarning:
# mpl_style had been deprecated and will be removed in a future version.
# Use `matplotlib.pyplot.style.use` instead.
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# # Yleisasiaa visualisoinnista

# %% [markdown]
# Kirjastoja:
# * Pandas
# * Matplotlib
# * ggplot
# * Bokeh
# * Seaborn
#
# Muita kirjastoja/työkaluja:
# * Pygal
# * Plotly
# * D3.js
