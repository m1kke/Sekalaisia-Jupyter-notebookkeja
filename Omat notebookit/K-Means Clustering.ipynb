# %% [markdown]
# # K-Means Clustering

# %%
#kirjastot
from sklearn.cluster import KMeans
import numpy as np
from bokeh.plotting import figure, show, output_notebook
from sklearn import datasets

# %%
# init bokeh
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="39edbe3d-482a-4f55-86c3-2cb4d10deffa">Loading BokehJS ...</span>
#     </div>

# %%
#ladataan data
iris = datasets.load_iris()

#otetaan vain tietyt sarakkeet
petal_data = iris.data[:,2:]

# %%
#alustetaan kmeans-algo
kmean = KMeans(n_clusters=3)

#ajetaan data sillä
kmean.fit(petal_data)
# Out:
# KMeans(copy_x=True, init='k-means++', max_iter=300, n_clusters=3, n_init=10,
#     n_jobs=1, precompute_distances='auto', random_state=None, tol=0.0001,
#     verbose=0)

# %%
#luodaan figure
plot = figure(width = 500, height = 500, title = "Iris petals", x_axis_label = "p. length", y_axis_label = "p. width")

# %%
clus_xs = []
clus_ys = []

# %%
# täytetään x ja y-arvot, append lisää arvon listan loppuun
for entry in kmean.cluster_centers_:
    clus_xs.append(entry[0])
    clus_ys.append(entry[1])

# %%
# luodaan figureen tarvittavat merkit ja tekstit
plot.circle_cross( x = clus_xs, y = clus_ys, size = 40, fill_alpha = 0, line_width = 2, color = ['red', 'blue', 'purple'])
plot.text(text = ["setosa", "versicolor", "virginica"], x = clus_xs, y = clus_ys, text_font_size = "30pt")

# %%
# alustetaan laskuri
i = 0

for sample in petal_data:
    if kmean.labels_[i] == 0:
        plot.circle(x = sample[0], y = sample[1], size = 15, color = "red")
    if kmean.labels_[i] == 1:
        plot.circle(x = sample[0], y = sample[1], size = 15, color = "blue")
    if kmean.labels_[i] == 2:
        plot.circle(x = sample[0], y = sample[1], size = 15, color = "purple")
    i += 1

# %%
show(plot)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="2719b26c-526e-4f4c-b1c7-d8298a82c68f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#2719b26c-526e-4f4c-b1c7-d8298a82c68f").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("2719b26c-526e-4f4c-b1c7-d8298a82c68f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '2719b26c-526e-4f4c-b1c7-d8298a82c68f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"eaf99aba-a6ed-415b-8599-9365b94e7917":{"roots":{"references":[{"attributes":{"fill_color":{"value":"red"},"line_color":{"value":"red"},"size":{"units":"screen","value":15},"x":{"value":4.5},"y":{"value":1.5}},"id":"1006c61a-09e0-4a64-8e2e-ce222e9f3ed8","type":"Circle"},{"attributes":{"fill_color":{"value":"blue"},"line_color":{"value":"blue"},"size":{"units":"screen","value":15},"x":{"value":5.6},"y":{"value":2.1}},"id":"5e060af7-bc00-4f82-9a4a-f71b73cf2a1f","type":"Circle"},{"attributes":{"data_source":{"id":"4b55558e-9833-41f4-8fc6-f5c2795a1109","type":"ColumnDataSource"},"glyph":{"id":"89ec1e9b-0bd0-4fad-81e3-3f1fb39b1f64","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"dc68248b-29f3-471a-8fc8-d1dcd68f6810","type":"Circle"},"selection_glyph":null},"id":"da9e9592-6d22-4359-bd87-c8b203cb70b0","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"c6ac5ecf-2efc-435f-a563-d1c31ba378e9","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"f28340ca-db33-4963-86ca-6398f733c643","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":15},"x":{"value":4.5},"y":{"value":1.5}},"id":"b3a46a45-8f26-4ea8-a0e7-5e16bc1c08a2","type":"Circle"},{"attributes":{"fill_color":{"value":"blue"},"line_color":{"value":"blue"},"size":{"units":"screen","value":15},"x":{"value":5.6},"y":{"value":1.8}},"id":"ad592771-42a7-4eb5-a7d6-7a4f6a528fcb","type":"Circle"},{"attributes":{"fill_color":{"value":"purple"},"line_color":{"value":"purple"},"size":{"units":"screen","value":15},"x":{"value":1.9},"y":{"value":0.2}},"id":"b10a60d2-66d3-47a5-9a31-fd67c7f543f9","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":15},"x":{"value":1.5},"y":{"value":0.4}},"id":"8733593a-9970-4224-a26a-dcf6b3be5722","type":"Circle"},{"attributes":{"fill_color":{"value":"blue"},"line_color":{"value":"blue"},"size":{"units":"screen","value":15},"x":{"value":5.8},"y":{"value":1.6}},"id":"27ca1d5e-7cea-498f-8dee-ace1c9ba2cb3","type":"Circle"},{"attributes":{"data_source":{"id":"f58cdb35-c604-4a30-8226-2991c6e7e889","type":"ColumnDataSource"},"glyph":{"id":"2948db11-5695-4118-9636-a76bcb43a605","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"fe875664-b5b2-40b6-8a7d-078d18fec56b","type":"Circle"},"selection_glyph":null},"id":"7fccb681-4fb2-4a1b-87fe-285795f7712b","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":15},"x":{"value":1.5},"y":{"value":0.2}},"id":"e78e8408-c637-48e2-a758-5b8a93bd45a0","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":15},"x":{"value":1.3},"y":{"value":0.2}},"id":"4e503d52-aec2-446d-9133-c7e91d4a18e4","type":"Circle"},{"attributes":{"overlay":{"id":"84fc0ca5-796c-40f8-9fe4-3af20e25867e","type":"BoxAnnotation"},"plot":{"id":"e90b74f3-0754-4a36-ace3-48c1219fd233","subtype":"Figure","type":"Plot"}},"id":"72789acb-8402-4607-86a8-d1146d122120","type":"BoxZoomTool"},{"attributes":{"callback":null},"id":"6c6999cd-2d83-4840-9d04-7759bd7afe1b","type":"ColumnDataSource"},{"attributes":{"fill_color":{"value":"purple"},"line_color":{"value":"purple"},"size":{"units":"screen","value":15},"x":{"value":1.5},"y":{"value":0.1}},"id":"998d4692-6a90-466e-89cf-0589488f2a61","type":"Circle"},{"attributes":{"callback":null},"id":"7893746f-11c8-46c1-8824-be674e0f24d8","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"e864cb7c-1697-42f2-8fc0-5a75d2d65759","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77 ...
